# %%
import pandas as pd

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix
from matplotlib import pyplot as plt
import seaborn as sns

from scale.plot import plot_embedding, plot_heatmap

# %%
y = pd.read_csv('results/filtered_seven_clusters_names_cicero_x_005_k_auto_step_lr/cluster_assignments.txt', sep='\t', index_col=0, header=None)[1].values

# %%
# !head results/filtered_seven_clusters_names_cicero_x_005_k_auto_step_lr/cluster_assignments.txt
# Out:
# cell_1	2
# cell_2	10
# cell_3	2
# cell_4	2
# cell_5	2
# cell_6	10
# cell_7	10
# cell_8	6
# cell_9	6
# cell_10	10

# %%
feature = pd.read_csv('results/filtered_seven_clusters_names_cicero_x_005_k_auto_step_lr/feature.txt', sep='\t', index_col=0, header=None)
plot_heatmap(feature.T, y, 
             figsize=(16, 8), cmap='RdBu_r', vmax=8, vmin=-8, center=0,
             ylabel='Feature dimension', yticklabels=np.arange(10)+1, 
             cax_title='Feature value', legend_font=6, ncol=1,
             bbox_to_anchor=(1.1, 1.1), position=(0.92, 0.15, .08, .04))
