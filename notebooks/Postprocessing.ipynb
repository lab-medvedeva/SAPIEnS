# %%
import pandas as pd

# %%
df = pd.read_csv('output_all/cluster_assignments_all.txt', sep='\t', header=None)

# %%
df2 = pd.read_csv('output_all/feature_all.txt', sep='\t', header=None)

# %%
df.columns = ['cell_id', 'cluster']

# %%
df2.columns = ['cell_num'] + [f'feature_{i}' for i in range(10)]

# %%
df2['cell_id'] = df.cell_id
df2['cluster'] = df.cluster

# %%
df2
# Out:
#       cell_num  feature_0  feature_1  feature_2  feature_3  feature_4  \
# 0            0  -2.057340  -8.103008  -6.123301  -3.743026  -5.281394
# 1            1  -2.300145  -5.191327  -4.879965  -2.423331  -5.606641
# 2            2  -0.922653  -4.792365  -6.407924  -2.701406  -5.330397
# 3            3  -1.493632  -5.342095  -7.472171  -1.668281  -5.546890
# 4            4  -1.805812  -5.847157  -6.323675  -2.749328  -5.787833
# ...        ...        ...        ...        ...        ...        ...
# 2931      2931  -6.006165  -2.969234  -0.342804  -2.167536  -1.283602
# 2932      2932  -2.091961  -3.491089  -2.905349  -4.882641  -5.157963
# 2933      2933  -5.460393  -2.648483  -0.345982  -0.522616  -3.172438
# 2934      2934  -1.744058  -2.913534  -4.973247  -2.133690  -5.221390
# 2935      2935  -3.767537  -4.486868  -0.149463  -3.041360  -7.566585
#
#       feature_5  feature_6  feature_7  feature_8  feature_9    cell_id  \
# ...

# %%
df2.to_csv('output_all/cell_info_all.tsv', sep='\t', index=None)

# %%
df = pd.read_csv('count_matrix_data/GSE96769_cell_names_matrix.csv')

# %%
df[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/PythonEnvironments/SpadePython37/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-b5f2749c85df> in <module>
# ----> 1 df[2]
#
# ...
